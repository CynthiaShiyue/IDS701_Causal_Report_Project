# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

url = "https://github.com/CynthiaShiyue/IDS701_Causal_Report_Project/raw/data/final_df.csv"
data = pd.read_csv(url)
data["Date"] = pd.to_datetime(data["Date"])
data["event_date"] = pd.to_datetime(data["event_date"])
data = data.dropna(subset=["event_id"])
data = data[data["event_time"] != -1]
data["event_time"] = data["event_time"].astype(float).astype(int)

# %% [markdown]
# 1. Select the data subset for each event
# 2. Skip the event if Treatment has no variation
# 3. Convert event_time to categorical
# 4. Run the regression: abnormal_return ~ C(event_time) * Treatment + C(ticker), clustered by ticker
# 5. Extract Treatment-related interaction terms
# 6. Generate confidence intervals
# 7. Keep event_time between -10 and 10
# 8. Plot dynamic Treatment Effects:
#    - x-axis: event time
#    - y-axis: Treatment Effect estimate
#    - Error bars: 95% confidence intervals
#    - Add dashed line at t = 0
#    - Add labels, legend, and grid

# %%
event_list = data['event_id'].unique()

for event in event_list:
    print(f"Processing event: {event}")
    
    df_event = data[data['event_id'] == event]
    
    if df_event['Treatment'].nunique() < 2:
        print(f"Skipping {event} because not enough variation in Treatment")
        continue
    
    df_event['event_time'] = df_event['event_time'].astype('category')
    
    model = smf.ols(
        formula="abnormal_return ~ C(event_time) * Treatment + C(ticker)",
        data=df_event
    ).fit(
        cov_type="cluster",
        cov_kwds={"groups": df_event["ticker"]}
    )
    
    coef = model.params
    conf = model.conf_int()
    
    treat_effect = coef[coef.index.str.contains(r'C\(event_time\)\[T\.-?\d+\]:Treatment')].reset_index()
    treat_effect.columns = ['term', 'coef']
    
    conf_treat = conf.loc[treat_effect['term']]
    treat_effect['lower'] = conf_treat[0].values
    treat_effect['upper'] = conf_treat[1].values
    
    treat_effect['event_time'] = treat_effect['term'].str.extract(r'\[T\.?(-?\d+)\]')[0].astype(int)
    
    treat_effect = treat_effect[treat_effect['event_time'].between(-10, 10)]
    treat_effect = treat_effect.sort_values('event_time')
    
    plt.figure(figsize=(8, 5))
    
    plt.errorbar(
        treat_effect['event_time'],
        treat_effect['coef'],
        yerr=[treat_effect['coef'] - treat_effect['lower'], treat_effect['upper'] - treat_effect['coef']],
        fmt='o', capsize=4, color='black', label='Estimate ± 95% CI'
    )
    plt.axhline(0, color='gray', linestyle='-')
    plt.axvline(0, color='gray', linestyle='--', label='Event Date (t = 0)')
    plt.xlim(-10.5, 10.5)
    plt.title(f'Dynamic Treatment Effects for {event}', fontsize=14)
    plt.xlabel('Event Time (Days)', fontsize=12)
    plt.ylabel('Treatment Effect on Abnormal Return', fontsize=12)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
# Out:
# Processing event: 2022_oct_china_chip_export_control
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2023_chip_export_controls
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2023_mineral_export_restrictions
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2023_aug_investment_ban
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2023_export_expansion
# Processing event: 2024_march_export_tightening
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2024_tariff_increase_ev_battery
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2024_tariff_finalization
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2726624573.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event['event_time'] = df_event['event_time'].astype('category')
# Processing event: 2024_nvidia_antitrust_probe

# %% [markdown]
# ---
#
# - Applied winsorization to abnormal_return at the 1% and 99% levels to reduce the influence of extreme outliers.
# - Changed the time window division:
#   - Instead of treating each event_time separately, grouped event_time into four bins: Pre_early, Pre_late, Post_early, and Post_late.
# - Updated the regression specification:
#   - Used C(time_bin) * Treatment instead of C(event_time) * Treatment.
#   - Still controlled for ticker fixed effects and used clustered standard errors by ticker.
# - Updated the plotting:
#   - x-axis changed from event_time (day-by-day) to time_bin (four periods).
#   - This makes the treatment effects easier to visualize and interpret across broader periods around the event.

# %%
from scipy.stats.mstats import winsorize 

winsorized_returns = winsorize(data["abnormal_return"], limits=[0.01, 0.01])
data["abnormal_return"] = winsorized_returns

event_list = data['event_id'].unique()

for event in event_list:
    print(f"Processing event: {event}")
    
    df_event = data[data['event_id'] == event]
    
    if df_event['Treatment'].nunique() < 2:
        print(f"Skipping {event} because not enough variation in Treatment")
        continue
    
    bins = [-15, -3, 0, 5, 15]
    labels = ["Pre_early", "Pre_late", "Post_early", "Post_late"]
    
    df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
    
    model = smf.ols(
        formula="abnormal_return ~ C(time_bin) * Treatment + C(ticker)",
        data=df_event
    ).fit(
        cov_type="cluster",
        cov_kwds={"groups": df_event["ticker"]}
    )
    
    coef = model.params
    conf = model.conf_int()
    
    treat_effect = coef[coef.index.str.contains(r'C\(time_bin\)\[T\..*\]:Treatment')].reset_index()
    treat_effect.columns = ['term', 'coef']
    
    conf_treat = conf.loc[treat_effect['term']]
    treat_effect['lower'] = conf_treat[0].values
    treat_effect['upper'] = conf_treat[1].values
    
    treat_effect['bin'] = treat_effect['term'].str.extract(r'\[T\.(.*)\]')[0]
    treat_effect['bin'] = pd.Categorical(treat_effect['bin'], categories=labels, ordered=True)
    treat_effect = treat_effect.sort_values('bin')
    
    plt.figure(figsize=(8, 5))
    
    plt.errorbar(
        treat_effect['bin'],
        treat_effect['coef'],
        yerr=[treat_effect['coef'] - treat_effect['lower'], treat_effect['upper'] - treat_effect['coef']],
        fmt='o', capsize=4, color='black', label='Estimate ± 95% CI'
    )
    plt.axhline(0, color='gray', linestyle='--')
    plt.title(f'Windowed Dynamic Effects for {event}', fontsize=14)
    plt.xlabel('Time Bin')
    plt.ylabel('Treatment Effect on Abnormal Return')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
# Out:
# Processing event: 2022_oct_china_chip_export_control
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\regression\linear_model.py:1884: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# Processing event: 2023_chip_export_controls
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2023_mineral_export_restrictions
# Processing event: 2023_aug_investment_ban
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2023_export_expansion
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_march_export_tightening
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_tariff_increase_ev_battery
# Processing event: 2024_tariff_finalization
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_nvidia_antitrust_probe
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2921888904.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)

# %% [markdown]
# ---
#
# - Added lagged_return and absolute_return as additional control variables in the regression model.
# - Dropped observations with missing values in lagged_return, absolute_return, or CAR_pre to ensure data completeness.
# - Updated the regression specification to:
#   abnormal_return ~ C(time_bin) * Treatment + C(ticker) + lagged_return + absolute_return + CAR_pre
# - This further controls for momentum effects and volatility, improving the robustness of the estimated treatment effects.

# %%
data["lagged_return"] = data.groupby("ticker")["Return"].shift(1)
data["absolute_return"] = data["Return"].abs()

winsorized_returns = winsorize(data["abnormal_return"], limits=[0.01, 0.01])
data["abnormal_return"] = winsorized_returns

data = data.dropna(subset=["lagged_return", "absolute_return", "CAR_pre"])

event_list = data['event_id'].unique()

for event in event_list:
    print(f"Processing event: {event}")
    
    df_event = data[data['event_id'] == event]
    
    if df_event['Treatment'].nunique() < 2:
        print(f"Skipping {event} because not enough variation in Treatment")
        continue
    
    bins = [-15, -3, 0, 5, 15]
    labels = ["Pre_early", "Pre_late", "Post_early", "Post_late"]
    
    df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
    
    model = smf.ols(
        formula="abnormal_return ~ C(time_bin) * Treatment + C(ticker) + lagged_return + absolute_return + CAR_pre",
        data=df_event
    ).fit(
        cov_type="cluster",
        cov_kwds={"groups": df_event["ticker"]}
    )
    
    coef = model.params
    conf = model.conf_int()
    
    treat_effect = coef[coef.index.str.contains(r'C\(time_bin\)\[T\..*\]:Treatment')].reset_index()
    treat_effect.columns = ['term', 'coef']
    
    conf_treat = conf.loc[treat_effect['term']]
    treat_effect['lower'] = conf_treat[0].values
    treat_effect['upper'] = conf_treat[1].values
    
    treat_effect['bin'] = treat_effect['term'].str.extract(r'\[T\.(.*)\]')[0]
    treat_effect['bin'] = pd.Categorical(treat_effect['bin'], categories=labels, ordered=True)
    treat_effect = treat_effect.sort_values('bin')
    
    plt.figure(figsize=(8, 5))
    
    plt.errorbar(
        treat_effect['bin'],
        treat_effect['coef'],
        yerr=[treat_effect['coef'] - treat_effect['lower'], treat_effect['upper'] - treat_effect['coef']],
        fmt='o', capsize=4, color='black', label='Estimate ± 95% CI'
    )
    plt.axhline(0, color='gray', linestyle='--')
    plt.title(f'Windowed Dynamic Effects (Add Lagged and Absolute Return) for {event}', fontsize=14)
    plt.xlabel('Time Bin')
    plt.ylabel('Treatment Effect on Abnormal Return')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
# Out:
# Processing event: 2022_oct_china_chip_export_control
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2023_chip_export_controls
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2023_mineral_export_restrictions
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2023_aug_investment_ban
# Processing event: 2023_export_expansion
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_march_export_tightening
# Processing event: 2024_tariff_increase_ev_battery
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_tariff_finalization
# C:\Users\Leo\AppData\Local\Temp\ipykernel_28912\2149201151.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_event["time_bin"] = pd.cut(df_event["event_time"], bins=bins, labels=labels)
# Processing event: 2024_nvidia_antitrust_probe

# %% [markdown]
# ---
#
# - Added industry classification (hardware, software, ETF) based on ticker information.
# - Included industry fixed effects C(industry) in the regression model to control for sector-specific influences.
# - Switched the standard error estimation from clustered standard errors to Newey-West HAC standard errors (cov_type='HAC') for better robustness against autocorrelation and heteroskedasticity.

# %%
import statsmodels.api as sm

data["lagged_return"] = data.groupby("ticker")["Return"].shift(1)
data["absolute_return"] = data["Return"].abs()
data["abnormal_return"] = winsorize(data["abnormal_return"], limits=[0.01, 0.01])
data = data.dropna(subset=["lagged_return", "absolute_return", "CAR_pre"])

hardware = ["NVDA", "AMD", "INTC"]
software = ["CRM", "ORCL", "ADBE"]
etf = ["QQQ"]

def map_industry(ticker):
    if ticker in hardware:
        return "hardware"
    elif ticker in software:
        return "software"
    else:
        return "etf"

data["industry"] = data["ticker"].apply(map_industry)

bins = [-15, -3, 0, 5, 15]
labels = ["Pre_early", "Pre_late", "Post_early", "Post_late"]
data["time_bin"] = pd.cut(data["event_time"], bins=bins, labels=labels)

event_list = data["event_id"].unique()

for event in event_list:
    print(f"Processing event: {event}")
    
    df_event = data[data["event_id"] == event]
    
    if df_event["Treatment"].nunique() < 2:
        print(f"Skipping {event} due to lack of variation in Treatment")
        continue

    model = smf.ols(
        formula="abnormal_return ~ C(time_bin) * Treatment + C(ticker) + C(industry) + lagged_return + absolute_return + CAR_pre",
        data=df_event
    ).fit(cov_type='HAC', cov_kwds={'maxlags':1})
    
    coef = model.params
    conf = model.conf_int()

    treat_effect = coef[coef.index.str.contains(r'C\(time_bin\)\[T\..*\]:Treatment')].reset_index()
    treat_effect.columns = ['term', 'coef']

    conf_treat = conf.loc[treat_effect['term']]
    treat_effect['lower'] = conf_treat[0].values
    treat_effect['upper'] = conf_treat[1].values

    treat_effect['bin'] = treat_effect['term'].str.extract(r'\[T\.(.*)\]')[0]
    treat_effect['bin'] = pd.Categorical(treat_effect['bin'], categories=labels, ordered=True)
    treat_effect = treat_effect.sort_values('bin')

    plt.figure(figsize=(8, 5))
    plt.errorbar(
        treat_effect['bin'],
        treat_effect['coef'],
        yerr=[treat_effect['coef'] - treat_effect['lower'], treat_effect['upper'] - treat_effect['coef']],
        fmt='o', capsize=4, color='black', label='Estimate ± 95% CI'
    )
    plt.axhline(0, color='gray', linestyle='--')
    plt.title(f'Windowed Dynamic Effects (Add Industry Variable) for {event}', fontsize=14)
    plt.xlabel('Time Bin')
    plt.ylabel('Treatment Effect on Abnormal Return')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
# Out:
# Processing event: 2022_oct_china_chip_export_control
# Processing event: 2023_chip_export_controls
# Processing event: 2023_mineral_export_restrictions
# Processing event: 2023_aug_investment_ban
# Processing event: 2023_export_expansion
# Processing event: 2024_march_export_tightening
# Processing event: 2024_tariff_increase_ev_battery
# Processing event: 2024_tariff_finalization
# Processing event: 2024_nvidia_antitrust_probe

# %%
# Regression Coefficients

model_dict = {}

for event in event_list:
    print(f"Processing event: {event}")
    
    df_event = data[data["event_id"] == event]
    
    if df_event["Treatment"].nunique() < 2:
        print(f"Skipping {event} due to lack of variation in Treatment")
        continue

    model = smf.ols(
        formula="abnormal_return ~ C(time_bin) * Treatment + C(ticker) + C(industry) + lagged_return + absolute_return + CAR_pre",
        data=df_event
    ).fit(cov_type='HAC', cov_kwds={'maxlags':1})

    model_dict[event] = model
    print(model.summary())
    print()
    print('-·'*60)
    print()
# Out:
# Processing event: 2022_oct_china_chip_export_control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     22.88
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           5.59e-26
# Time:                        02:34:01   Log-Likelihood:                 257.06
# No. Observations:                 102   AIC:                            -468.1
# Df Residuals:                      79   BIC:                            -407.7
# Df Model:                          22
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0027      0.003     -1.010      0.313      -0.008       0.003
# C(time_bin)[T.Pre_late]                -0.0074      0.004     -1.873      0.061      -0.015       0.000
# C(time_bin)[T.Post_early]              -0.0069      0.003     -1.972      0.049      -0.014   -4.23e-05
# C(time_bin)[T.Post_late]                0.0115      0.003      3.311      0.001       0.005       0.018
# C(ticker)[T.AMD]                       -0.0036      0.007     -0.533      0.594      -0.017       0.010
# C(ticker)[T.AVGO]                      -0.0076      0.005     -1.557      0.120      -0.017       0.002
# C(ticker)[T.CRM]                       -0.0065      0.008     -0.839      0.402      -0.022       0.009
# C(ticker)[T.CRWD]                      -0.0132      0.004     -3.174      0.002      -0.021      -0.005
# C(ticker)[T.CSCO]                       0.0079      0.006      1.383      0.167      -0.003       0.019
# C(ticker)[T.INTC]                       0.0097      0.008      1.224      0.221      -0.006       0.025
# C(ticker)[T.INTU]                       0.0025      0.006      0.429      0.668      -0.009       0.014
# C(ticker)[T.MDB]                       -0.0042      0.005     -0.767      0.443      -0.015       0.006
# C(ticker)[T.MRVL]                      -0.0080      0.007     -1.141      0.254      -0.022       0.006
# C(ticker)[T.MU]                         0.0188      0.011      1.785      0.074      -0.002       0.040
# C(ticker)[T.NOW]                       -0.0122      0.005     -2.463      0.014      -0.022      -0.002
# C(ticker)[T.NVDA]                      -0.0034      0.008     -0.446      0.655      -0.018       0.012
# C(ticker)[T.ORCL]                       0.0039      0.010      0.385      0.700      -0.016       0.024
# C(ticker)[T.QCOM]                      -0.0009      0.006     -0.145      0.885      -0.014       0.012
# C(ticker)[T.QQQ]                        0.0028      0.004      0.651      0.515      -0.006       0.011
# C(ticker)[T.TSM]                       -0.0003      0.008     -0.034      0.973      -0.016       0.016
# C(industry)[T.hardware]                 0.0026      0.004      0.662      0.508      -0.005       0.010
# C(industry)[T.software]                 0.0091      0.006      1.542      0.123      -0.002       0.021
# Treatment                               0.0046      0.003      1.847      0.065      -0.000       0.010
# C(time_bin)[T.Pre_late]:Treatment      -0.0001      0.005     -0.020      0.984      -0.010       0.010
# C(time_bin)[T.Post_early]:Treatment    -0.0075      0.004     -1.980      0.048      -0.015   -7.57e-05
# C(time_bin)[T.Post_late]:Treatment      0.0123      0.006      2.212      0.027       0.001       0.023
# lagged_return                          -0.2236      0.110     -2.024      0.043      -0.440      -0.007
# absolute_return                        -0.6920      0.130     -5.304      0.000      -0.948      -0.436
# CAR_pre                                -0.0011      0.001     -1.712      0.087      -0.002       0.000
# ==============================================================================
# Omnibus:                        9.462   Durbin-Watson:                   2.387
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.314
# Skew:                           0.697   Prob(JB):                      0.00949
# Kurtosis:                       3.496   Cond. No.                     5.02e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 7.75e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2023_chip_export_controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     14.27
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           7.91e-28
# Time:                        02:34:01   Log-Likelihood:                 382.85
# No. Observations:                 170   AIC:                            -715.7
# Df Residuals:                     145   BIC:                            -637.3
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0018      0.004      0.427      0.670      -0.006       0.010
# C(time_bin)[T.Pre_late]                -0.0087      0.004     -1.962      0.050      -0.017   -9.87e-06
# C(time_bin)[T.Post_early]              -0.0097      0.005     -1.823      0.068      -0.020       0.001
# C(time_bin)[T.Post_late]               -0.0212      0.007     -2.993      0.003      -0.035      -0.007
# C(ticker)[T.AMD]                       -0.0016      0.007     -0.233      0.816      -0.015       0.012
# C(ticker)[T.AVGO]                      -0.0018      0.004     -0.433      0.665      -0.010       0.007
# C(ticker)[T.CRM]                        0.0119      0.006      1.889      0.059      -0.000       0.024
# C(ticker)[T.CRWD]                       0.0066      0.009      0.753      0.452      -0.011       0.024
# C(ticker)[T.CSCO]                       0.0044      0.003      1.304      0.192      -0.002       0.011
# C(ticker)[T.INTC]                      -0.0015      0.010     -0.153      0.878      -0.020       0.017
# C(ticker)[T.INTU]                      -0.0005      0.008     -0.069      0.945      -0.016       0.015
# C(ticker)[T.MDB]                       -0.0169      0.012     -1.414      0.157      -0.040       0.007
# C(ticker)[T.MRVL]                       0.0005      0.009      0.064      0.949      -0.016       0.017
# C(ticker)[T.MU]                         0.0023      0.006      0.387      0.699      -0.009       0.014
# C(ticker)[T.NOW]                       -0.0012      0.007     -0.167      0.867      -0.015       0.013
# C(ticker)[T.NVDA]                       0.0028      0.008      0.341      0.733      -0.013       0.019
# C(ticker)[T.ORCL]                       0.0026      0.007      0.364      0.716      -0.011       0.016
# C(ticker)[T.QCOM]                       0.0070      0.004      1.643      0.100      -0.001       0.015
# C(ticker)[T.QQQ]                        0.0062      0.005      1.361      0.173      -0.003       0.015
# C(ticker)[T.TSM]                       -0.0037      0.005     -0.729      0.466      -0.014       0.006
# C(industry)[T.hardware]                -0.0003      0.004     -0.094      0.925      -0.007       0.007
# C(industry)[T.software]                -0.0005      0.005     -0.101      0.919      -0.011       0.010
# Treatment                               0.0039      0.003      1.253      0.210      -0.002       0.010
# C(time_bin)[T.Pre_late]:Treatment      -0.0098      0.009     -1.076      0.282      -0.028       0.008
# C(time_bin)[T.Post_early]:Treatment    -0.0113      0.009     -1.292      0.196      -0.028       0.006
# C(time_bin)[T.Post_late]:Treatment      0.0074      0.010      0.767      0.443      -0.012       0.026
# lagged_return                          -0.1725      0.065     -2.643      0.008      -0.300      -0.045
# absolute_return                         0.6534      0.152      4.292      0.000       0.355       0.952
# CAR_pre                                 0.0018      0.001      1.322      0.186      -0.001       0.005
# ==============================================================================
# Omnibus:                       36.530   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.056
# Skew:                          -1.064   Prob(JB):                     2.03e-14
# Kurtosis:                       5.091   Cond. No.                     1.23e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 1.84e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2023_mineral_export_restrictions
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     9.954
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           1.12e-19
# Time:                        02:34:01   Log-Likelihood:                 457.62
# No. Observations:                 153   AIC:                            -865.2
# Df Residuals:                     128   BIC:                            -789.5
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0057      0.002     -2.375      0.018      -0.010      -0.001
# C(time_bin)[T.Pre_late]                -0.0028      0.003     -0.873      0.383      -0.009       0.004
# C(time_bin)[T.Post_early]               0.0050      0.004      1.382      0.167      -0.002       0.012
# C(time_bin)[T.Post_late]                0.0048      0.004      1.290      0.197      -0.002       0.012
# C(ticker)[T.AMD]                       -0.0028      0.004     -0.701      0.484      -0.011       0.005
# C(ticker)[T.AVGO]                       0.0004      0.002      0.203      0.839      -0.004       0.005
# C(ticker)[T.CRM]                        0.0053      0.004      1.471      0.141      -0.002       0.012
# C(ticker)[T.CRWD]                      -0.0032      0.005     -0.710      0.478      -0.012       0.006
# C(ticker)[T.CSCO]                      -0.0023      0.005     -0.443      0.658      -0.012       0.008
# C(ticker)[T.INTC]                       0.0010      0.004      0.247      0.805      -0.007       0.009
# C(ticker)[T.INTU]                       0.0049      0.004      1.384      0.166      -0.002       0.012
# C(ticker)[T.MDB]                       -0.0183      0.004     -4.853      0.000      -0.026      -0.011
# C(ticker)[T.MRVL]                      -0.0039      0.004     -0.989      0.323      -0.012       0.004
# C(ticker)[T.MU]                        -0.0032      0.005     -0.687      0.492      -0.012       0.006
# C(ticker)[T.NOW]                        0.0027      0.002      1.274      0.203      -0.001       0.007
# C(ticker)[T.NVDA]                       0.0021      0.004      0.572      0.567      -0.005       0.009
# C(ticker)[T.ORCL]                      -0.0062      0.004     -1.519      0.129      -0.014       0.002
# C(ticker)[T.QCOM]                       0.0073      0.003      2.771      0.006       0.002       0.012
# C(ticker)[T.QQQ]                        0.0036      0.002      2.119      0.034       0.000       0.007
# C(ticker)[T.TSM]                        0.0034      0.002      1.676      0.094      -0.001       0.007
# C(industry)[T.hardware]                 0.0003      0.002      0.159      0.874      -0.004       0.004
# C(industry)[T.software]                 0.0026      0.002      1.094      0.274      -0.002       0.007
# Treatment                               0.0044      0.003      1.581      0.114      -0.001       0.010
# C(time_bin)[T.Pre_late]:Treatment      -0.0193      0.005     -3.679      0.000      -0.030      -0.009
# C(time_bin)[T.Post_early]:Treatment    -0.0029      0.005     -0.571      0.568      -0.013       0.007
# C(time_bin)[T.Post_late]:Treatment     -0.0091      0.005     -1.797      0.072      -0.019       0.001
# lagged_return                          -0.2597      0.048     -5.418      0.000      -0.354      -0.166
# absolute_return                         0.5710      0.122      4.691      0.000       0.332       0.810
# CAR_pre                                 0.0013      0.000      3.966      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                       38.702   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.122
# Skew:                          -1.253   Prob(JB):                     1.19e-14
# Kurtosis:                       4.943   Cond. No.                     1.98e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 6.57e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2023_aug_investment_ban
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     16.63
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           4.08e-31
# Time:                        02:34:01   Log-Likelihood:                 444.20
# No. Observations:                 170   AIC:                            -838.4
# Df Residuals:                     145   BIC:                            -760.0
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0112      0.003     -3.302      0.001      -0.018      -0.005
# C(time_bin)[T.Pre_late]                 0.0106      0.003      3.639      0.000       0.005       0.016
# C(time_bin)[T.Post_early]               0.0201      0.003      5.855      0.000       0.013       0.027
# C(time_bin)[T.Post_late]                0.0061      0.003      2.032      0.042       0.000       0.012
# C(ticker)[T.AMD]                        0.0049      0.007      0.662      0.508      -0.010       0.019
# C(ticker)[T.AVGO]                      -0.0031      0.005     -0.616      0.538      -0.013       0.007
# C(ticker)[T.CRM]                        0.0057      0.004      1.376      0.169      -0.002       0.014
# C(ticker)[T.CRWD]                       0.0018      0.004      0.473      0.636      -0.006       0.009
# C(ticker)[T.CSCO]                       0.0032      0.003      1.087      0.277      -0.003       0.009
# C(ticker)[T.INTC]                       0.0020      0.005      0.410      0.682      -0.007       0.011
# C(ticker)[T.INTU]                       0.0033      0.003      1.172      0.241      -0.002       0.009
# C(ticker)[T.MDB]                       -0.0108      0.005     -2.157      0.031      -0.021      -0.001
# C(ticker)[T.MRVL]                      -0.0058      0.007     -0.825      0.409      -0.020       0.008
# C(ticker)[T.MU]                         0.0099      0.007      1.372      0.170      -0.004       0.024
# C(ticker)[T.NOW]                       -0.0036      0.002     -1.668      0.095      -0.008       0.001
# C(ticker)[T.NVDA]                      -0.0021      0.008     -0.255      0.799      -0.018       0.014
# C(ticker)[T.ORCL]                       0.0084      0.006      1.347      0.178      -0.004       0.021
# C(ticker)[T.QCOM]                      -0.0043      0.004     -1.096      0.273      -0.012       0.003
# C(ticker)[T.QQQ]                       -0.0019      0.003     -0.726      0.468      -0.007       0.003
# C(ticker)[T.TSM]                        0.0011      0.004      0.294      0.769      -0.006       0.008
# C(industry)[T.hardware]                 0.0047      0.004      1.303      0.192      -0.002       0.012
# C(industry)[T.software]                -0.0056      0.004     -1.569      0.117      -0.012       0.001
# Treatment                               0.0024      0.004      0.681      0.496      -0.005       0.009
# C(time_bin)[T.Pre_late]:Treatment      -0.0076      0.005     -1.390      0.164      -0.018       0.003
# C(time_bin)[T.Post_early]:Treatment    -0.0071      0.008     -0.935      0.350      -0.022       0.008
# C(time_bin)[T.Post_late]:Treatment     -0.0108      0.005     -2.055      0.040      -0.021      -0.000
# lagged_return                          -0.2082      0.071     -2.927      0.003      -0.348      -0.069
# absolute_return                        -0.5571      0.177     -3.150      0.002      -0.904      -0.210
# CAR_pre                                 0.0041      0.001      3.534      0.000       0.002       0.006
# ==============================================================================
# Omnibus:                       54.463   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.511
# Skew:                           1.274   Prob(JB):                     3.12e-36
# Kurtosis:                       7.074   Cond. No.                     8.53e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 3.83e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2023_export_expansion
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     7.739
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           1.71e-16
# Time:                        02:34:01   Log-Likelihood:                 484.14
# No. Observations:                 170   AIC:                            -918.3
# Df Residuals:                     145   BIC:                            -839.9
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0019      0.002      0.966      0.334      -0.002       0.006
# C(time_bin)[T.Pre_late]                 0.0045      0.005      0.915      0.360      -0.005       0.014
# C(time_bin)[T.Post_early]              -0.0095      0.003     -2.860      0.004      -0.016      -0.003
# C(time_bin)[T.Post_late]                0.0066      0.004      1.794      0.073      -0.001       0.014
# C(ticker)[T.AMD]                       -0.0004      0.003     -0.118      0.906      -0.007       0.006
# C(ticker)[T.AVGO]                       0.0061      0.005      1.231      0.218      -0.004       0.016
# C(ticker)[T.CRM]                       -0.0045      0.007     -0.689      0.491      -0.017       0.008
# C(ticker)[T.CRWD]                       0.0005      0.004      0.124      0.901      -0.008       0.009
# C(ticker)[T.CSCO]                      -0.0030      0.002     -1.479      0.139      -0.007       0.001
# C(ticker)[T.INTC]                      -0.0043      0.004     -1.190      0.234      -0.011       0.003
# C(ticker)[T.INTU]                      -0.0066      0.003     -2.628      0.009      -0.012      -0.002
# C(ticker)[T.MDB]                        0.0004      0.005      0.080      0.936      -0.009       0.009
# C(ticker)[T.MRVL]                      -0.0052      0.003     -1.599      0.110      -0.012       0.001
# C(ticker)[T.MU]                        -0.0033      0.003     -1.319      0.187      -0.008       0.002
# C(ticker)[T.NOW]                        0.0031      0.004      0.779      0.436      -0.005       0.011
# C(ticker)[T.NVDA]                       0.0031      0.006      0.547      0.584      -0.008       0.014
# C(ticker)[T.ORCL]                      -0.0082      0.006     -1.319      0.187      -0.020       0.004
# C(ticker)[T.QCOM]                      -0.0008      0.003     -0.263      0.793      -0.007       0.005
# C(ticker)[T.QQQ]                       -0.0008      0.002     -0.384      0.701      -0.005       0.003
# C(ticker)[T.TSM]                        0.0084      0.006      1.509      0.131      -0.003       0.019
# C(industry)[T.hardware]                -0.0016      0.002     -0.698      0.485      -0.006       0.003
# C(industry)[T.software]                 0.0049      0.005      0.919      0.358      -0.006       0.015
# Treatment                               0.0035      0.003      1.220      0.222      -0.002       0.009
# C(time_bin)[T.Pre_late]:Treatment      -0.0165      0.008     -2.163      0.031      -0.031      -0.002
# C(time_bin)[T.Post_early]:Treatment    -0.0013      0.005     -0.263      0.792      -0.011       0.008
# C(time_bin)[T.Post_late]:Treatment      0.0009      0.006      0.155      0.877      -0.011       0.013
# lagged_return                          -0.1029      0.079     -1.307      0.191      -0.257       0.051
# absolute_return                        -0.3889      0.165     -2.351      0.019      -0.713      -0.065
# CAR_pre                                 0.0014      0.001      2.242      0.025       0.000       0.003
# ==============================================================================
# Omnibus:                       14.974   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.463
# Skew:                           0.672   Prob(JB):                     0.000266
# Kurtosis:                       3.721   Cond. No.                     1.46e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 1.27e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2024_march_export_tightening
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     2.956
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           3.63e-05
# Time:                        02:34:01   Log-Likelihood:                 398.90
# No. Observations:                 153   AIC:                            -747.8
# Df Residuals:                     128   BIC:                            -672.0
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0026      0.002     -1.269      0.204      -0.007       0.001
# C(time_bin)[T.Pre_late]                -0.0020      0.005     -0.409      0.683      -0.012       0.008
# C(time_bin)[T.Post_early]              -0.0045      0.003     -1.612      0.107      -0.010       0.001
# C(time_bin)[T.Post_late]                0.0018      0.006      0.322      0.747      -0.009       0.013
# C(ticker)[T.AMD]                       -0.0028      0.005     -0.528      0.597      -0.013       0.008
# C(ticker)[T.AVGO]                      -0.0058      0.004     -1.399      0.162      -0.014       0.002
# C(ticker)[T.CRM]                       -0.0008      0.005     -0.149      0.881      -0.011       0.010
# C(ticker)[T.CRWD]                      -0.0075      0.003     -2.207      0.027      -0.014      -0.001
# C(ticker)[T.CSCO]                       0.0014      0.003      0.556      0.578      -0.004       0.006
# C(ticker)[T.INTC]                       0.0007      0.009      0.078      0.937      -0.016       0.018
# C(ticker)[T.INTU]                      -0.0028      0.004     -0.671      0.502      -0.011       0.005
# C(ticker)[T.MDB]                        0.0006      0.007      0.089      0.929      -0.013       0.014
# C(ticker)[T.MRVL]                       0.0098      0.008      1.170      0.242      -0.007       0.026
# C(ticker)[T.MU]                         0.0177      0.006      2.976      0.003       0.006       0.029
# C(ticker)[T.NOW]                        0.0019      0.004      0.512      0.609      -0.005       0.009
# C(ticker)[T.NVDA]                      -0.0079      0.007     -1.091      0.275      -0.022       0.006
# C(ticker)[T.ORCL]                      -0.0007      0.004     -0.159      0.874      -0.009       0.008
# C(ticker)[T.QCOM]                      -0.0020      0.004     -0.462      0.644      -0.010       0.006
# C(ticker)[T.QQQ]                        0.0001      0.002      0.044      0.965      -0.005       0.005
# C(ticker)[T.TSM]                       -0.0033      0.005     -0.703      0.482      -0.013       0.006
# C(industry)[T.hardware]                -0.0100      0.004     -2.754      0.006      -0.017      -0.003
# C(industry)[T.software]                -0.0028      0.004     -0.767      0.443      -0.010       0.004
# Treatment                               0.0064      0.003      1.919      0.055      -0.000       0.013
# C(time_bin)[T.Pre_late]:Treatment       0.0061      0.012      0.511      0.609      -0.017       0.029
# C(time_bin)[T.Post_early]:Treatment     0.0036      0.006      0.597      0.550      -0.008       0.015
# C(time_bin)[T.Post_late]:Treatment     -0.0253      0.008     -3.235      0.001      -0.041      -0.010
# lagged_return                          -0.2736      0.110     -2.489      0.013      -0.489      -0.058
# absolute_return                         0.0437      0.267      0.164      0.870      -0.480       0.568
# CAR_pre                                 0.0033      0.001      2.946      0.003       0.001       0.005
# ==============================================================================
# Omnibus:                       11.623   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               27.371
# Skew:                          -0.176   Prob(JB):                     1.14e-06
# Kurtosis:                       5.042   Cond. No.                     6.43e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 6.08e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2024_tariff_increase_ev_battery
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     15.89
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           4.11e-30
# Time:                        02:34:01   Log-Likelihood:                 517.81
# No. Observations:                 170   AIC:                            -985.6
# Df Residuals:                     145   BIC:                            -907.2
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0063      0.002     -3.577      0.000      -0.010      -0.003
# C(time_bin)[T.Pre_late]                 0.0028      0.004      0.655      0.513      -0.006       0.011
# C(time_bin)[T.Post_early]               0.0055      0.003      1.863      0.062      -0.000       0.011
# C(time_bin)[T.Post_late]                0.0028      0.003      0.874      0.382      -0.004       0.009
# C(ticker)[T.AMD]                        0.0058      0.003      2.138      0.032       0.000       0.011
# C(ticker)[T.AVGO]                      -0.0013      0.004     -0.341      0.733      -0.009       0.006
# C(ticker)[T.CRM]                        0.0002      0.003      0.068      0.946      -0.006       0.007
# C(ticker)[T.CRWD]                       0.0038      0.004      1.088      0.276      -0.003       0.011
# C(ticker)[T.CSCO]                      -0.0074      0.006     -1.220      0.222      -0.019       0.005
# C(ticker)[T.INTC]                       0.0009      0.003      0.262      0.793      -0.006       0.008
# C(ticker)[T.INTU]                       0.0022      0.003      0.700      0.484      -0.004       0.009
# C(ticker)[T.MDB]                       -0.0013      0.004     -0.325      0.746      -0.009       0.006
# C(ticker)[T.MRVL]                      -0.0044      0.003     -1.551      0.121      -0.010       0.001
# C(ticker)[T.MU]                        -0.0091      0.003     -2.652      0.008      -0.016      -0.002
# C(ticker)[T.NOW]                        0.0015      0.003      0.498      0.619      -0.005       0.008
# C(ticker)[T.NVDA]                      -0.0064      0.003     -1.914      0.056      -0.013       0.000
# C(ticker)[T.ORCL]                       0.0030      0.003      1.028      0.304      -0.003       0.009
# C(ticker)[T.QCOM]                       0.0051      0.002      2.680      0.007       0.001       0.009
# C(ticker)[T.QQQ]                        0.0045      0.001      3.330      0.001       0.002       0.007
# C(ticker)[T.TSM]                        0.0013      0.004      0.333      0.739      -0.007       0.009
# C(industry)[T.hardware]                 0.0002      0.002      0.130      0.897      -0.003       0.004
# C(industry)[T.software]                -0.0015      0.002     -0.708      0.479      -0.006       0.003
# Treatment                              -0.0081      0.002     -4.003      0.000      -0.012      -0.004
# C(time_bin)[T.Pre_late]:Treatment       0.0119      0.006      2.117      0.034       0.001       0.023
# C(time_bin)[T.Post_early]:Treatment     0.0036      0.005      0.760      0.447      -0.006       0.013
# C(time_bin)[T.Post_late]:Treatment      0.0074      0.004      1.847      0.065      -0.000       0.015
# lagged_return                          -0.2823      0.059     -4.780      0.000      -0.398      -0.167
# absolute_return                         0.9299      0.098      9.493      0.000       0.738       1.122
# CAR_pre                              1.357e-05      0.000      0.045      0.964      -0.001       0.001
# ==============================================================================
# Omnibus:                       29.819   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.416
# Skew:                          -1.074   Prob(JB):                     2.76e-09
# Kurtosis:                       3.975   Cond. No.                     1.97e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 6.99e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2024_tariff_finalization
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     11.16
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           6.64e-23
# Time:                        02:34:01   Log-Likelihood:                 412.15
# No. Observations:                 170   AIC:                            -774.3
# Df Residuals:                     145   BIC:                            -695.9
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0038      0.004     -0.930      0.353      -0.012       0.004
# C(time_bin)[T.Pre_late]                 0.0058      0.006      0.986      0.324      -0.006       0.017
# C(time_bin)[T.Post_early]              -0.0043      0.005     -0.894      0.371      -0.014       0.005
# C(time_bin)[T.Post_late]                0.0151      0.006      2.725      0.006       0.004       0.026
# C(ticker)[T.AMD]                        0.0007      0.005      0.128      0.898      -0.010       0.011
# C(ticker)[T.AVGO]                      -0.0024      0.010     -0.243      0.808      -0.022       0.017
# C(ticker)[T.CRM]                        0.0207      0.011      1.952      0.051   -8.53e-05       0.041
# C(ticker)[T.CRWD]                       0.0173      0.007      2.393      0.017       0.003       0.032
# C(ticker)[T.CSCO]                       0.0026      0.003      0.906      0.365      -0.003       0.008
# C(ticker)[T.INTC]                       0.0090      0.006      1.392      0.164      -0.004       0.022
# C(ticker)[T.INTU]                      -0.0011      0.004     -0.292      0.770      -0.009       0.006
# C(ticker)[T.MDB]                       -0.0100      0.006     -1.673      0.094      -0.022       0.002
# C(ticker)[T.MRVL]                      -0.0029      0.008     -0.372      0.710      -0.018       0.012
# C(ticker)[T.MU]                         0.0024      0.005      0.512      0.609      -0.007       0.012
# C(ticker)[T.NOW]                        0.0052      0.003      1.574      0.115      -0.001       0.012
# C(ticker)[T.NVDA]                      -0.0072      0.006     -1.237      0.216      -0.019       0.004
# C(ticker)[T.ORCL]                       0.0237      0.013      1.819      0.069      -0.002       0.049
# C(ticker)[T.QCOM]                       0.0014      0.006      0.258      0.796      -0.009       0.012
# C(ticker)[T.QQQ]                        0.0026      0.004      0.657      0.511      -0.005       0.010
# C(ticker)[T.TSM]                       -0.0041      0.006     -0.738      0.460      -0.015       0.007
# C(industry)[T.hardware]                 0.0025      0.004      0.702      0.483      -0.005       0.010
# C(industry)[T.software]                -0.0173      0.009     -1.849      0.064      -0.036       0.001
# Treatment                              -0.0030      0.006     -0.495      0.621      -0.015       0.009
# C(time_bin)[T.Pre_late]:Treatment       0.0331      0.010      3.203      0.001       0.013       0.053
# C(time_bin)[T.Post_early]:Treatment     0.0021      0.009      0.222      0.824      -0.016       0.020
# C(time_bin)[T.Post_late]:Treatment      0.0065      0.009      0.736      0.462      -0.011       0.024
# lagged_return                          -0.1918      0.071     -2.703      0.007      -0.331      -0.053
# absolute_return                         0.2821      0.197      1.429      0.153      -0.105       0.669
# CAR_pre                                 0.0028      0.002      1.475      0.140      -0.001       0.007
# ==============================================================================
# Omnibus:                       35.492   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.811
# Skew:                          -0.891   Prob(JB):                     6.32e-19
# Kurtosis:                       5.942   Cond. No.                     4.47e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 1.39e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
#
# Processing event: 2024_nvidia_antitrust_probe
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        abnormal_return   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     5.686
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           5.19e-12
# Time:                        02:34:01   Log-Likelihood:                 398.30
# No. Observations:                 170   AIC:                            -746.6
# Df Residuals:                     145   BIC:                            -668.2
# Df Model:                          24
# Covariance Type:                  HAC
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0077      0.003      2.423      0.015       0.001       0.014
# C(time_bin)[T.Pre_late]                -0.0339      0.010     -3.288      0.001      -0.054      -0.014
# C(time_bin)[T.Post_early]              -0.0210      0.006     -3.497      0.000      -0.033      -0.009
# C(time_bin)[T.Post_late]               -0.0147      0.005     -3.077      0.002      -0.024      -0.005
# C(ticker)[T.AMD]                        0.0020      0.005      0.420      0.675      -0.007       0.011
# C(ticker)[T.AVGO]                       0.0145      0.006      2.425      0.015       0.003       0.026
# C(ticker)[T.CRM]                        0.0072      0.013      0.566      0.571      -0.018       0.032
# C(ticker)[T.CRWD]                       0.0118      0.006      1.873      0.061      -0.001       0.024
# C(ticker)[T.CSCO]                       0.0008      0.004      0.223      0.824      -0.006       0.008
# C(ticker)[T.INTC]                      -0.0140      0.007     -2.079      0.038      -0.027      -0.001
# C(ticker)[T.INTU]                       0.0090      0.006      1.502      0.133      -0.003       0.021
# C(ticker)[T.MDB]                       -0.0168      0.009     -1.938      0.053      -0.034       0.000
# C(ticker)[T.MRVL]                      -0.0018      0.009     -0.200      0.841      -0.020       0.016
# C(ticker)[T.MU]                         0.0006      0.007      0.081      0.936      -0.014       0.015
# C(ticker)[T.NOW]                        0.0074      0.005      1.359      0.174      -0.003       0.018
# C(ticker)[T.NVDA]                      -0.0010      0.007     -0.158      0.875      -0.014       0.012
# C(ticker)[T.ORCL]                      -0.0055      0.012     -0.459      0.646      -0.029       0.018
# C(ticker)[T.QCOM]                      -0.0073      0.004     -2.065      0.039      -0.014      -0.000
# C(ticker)[T.QQQ]                        0.0074      0.005      1.633      0.102      -0.001       0.016
# C(ticker)[T.TSM]                       -0.0011      0.005     -0.225      0.822      -0.011       0.009
# C(industry)[T.hardware]                -0.0130      0.004     -3.660      0.000      -0.020      -0.006
# C(industry)[T.software]                -0.0036      0.010     -0.354      0.724      -0.024       0.016
# Treatment                              -0.0082      0.003     -2.379      0.017      -0.015      -0.001
# C(time_bin)[T.Pre_late]:Treatment       0.0023      0.013      0.185      0.853      -0.022       0.027
# C(time_bin)[T.Post_early]:Treatment     0.0313      0.008      3.808      0.000       0.015       0.047
# C(time_bin)[T.Post_late]:Treatment      0.0219      0.010      2.234      0.026       0.003       0.041
# lagged_return                          -0.1940      0.068     -2.846      0.004      -0.328      -0.060
# absolute_return                         0.1633      0.100      1.629      0.103      -0.033       0.360
# CAR_pre                                 0.0017      0.002      0.863      0.388      -0.002       0.006
# ==============================================================================
# Omnibus:                       16.023   Durbin-Watson:                   2.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.514
# Skew:                          -0.451   Prob(JB):                     3.90e-07
# Kurtosis:                       4.832   Cond. No.                     7.73e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The smallest eigenvalue is 4.54e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# -·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·-·
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 23
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\Leo\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 25
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ---
#
# - Extracts the treatment effect estimates at the Post_late stage for each event from the regression results.
# - Collects the point estimates and their 95% confidence intervals into a DataFrame.
# - Plots the Post_late treatment effects across different events with error bars representing confidence intervals.
# - Helps to visually compare the strength and significance of the treatment effects at the Post_late period for all events.

# %%
post_late_results = []

for event, model in model_dict.items():
    coef = model.params
    conf = model.conf_int()
    treat_terms = coef.index[coef.index.str.contains('C\\(time_bin\\)\\[T.Post_late\\]:Treatment')]
    term = treat_terms[0]
    post_late_results.append({
        "event": event,
        "coef": coef[term],
        "lower": conf.loc[term][0],
        "upper": conf.loc[term][1]
    })


post_late_df = pd.DataFrame(post_late_results)

plt.figure(figsize=(10, 6))
plt.errorbar(
    post_late_df["event"],
    post_late_df["coef"],
    yerr=[post_late_df["coef"] - post_late_df["lower"], post_late_df["upper"] - post_late_df["coef"]],
    fmt='o', capsize=4, color='black'
)
plt.axhline(0, color='gray', linestyle='--')
plt.xticks(rotation=45, ha='right')
plt.title("Treatment Effects at Post_late Stage Across Events", fontsize=14)
plt.xlabel("Event")
plt.ylabel("Treatment Effect on Abnormal Return")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
summary_results = []

for event in event_list:
    df_event = data[data['event_id'] == event]
    treat_group = df_event[df_event['Treatment'] == 1]
    treat_mean = treat_group.groupby('event_time')['abnormal_return'].mean()
    ar_day_0 = treat_mean.loc[0] if 0 in treat_mean.index else None
    ar_day_1 = treat_mean.loc[1] if 1 in treat_mean.index else None
    ar_day_5 = treat_mean.loc[5] if 5 in treat_mean.index else None

    if ar_day_0 is not None and ar_day_1 is not None:
        change_1day = ar_day_1 - ar_day_0
    else:
        change_1day = None

    if ar_day_0 is not None and ar_day_5 is not None:
        change_5day = ar_day_5 - ar_day_0
    else:
        change_5day = None

    summary_results.append({
        'event_id': event,
        'change_1day': change_1day,
        'change_5day': change_5day
    })

    plt.figure(figsize=(6,4))
    plt.plot(treat_mean.index, treat_mean.values, marker='o', label='Treatment Group AR')
    plt.axvline(0, color='red', linestyle='--')
    plt.title(f'AR around {event}')
    plt.xlabel('Event Time (Days)')
    plt.ylabel('Average Abnormal Return')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

summary_df = pd.DataFrame(summary_results)
print(summary_df)
# Out:
#                              event_id  change_1day  change_5day
# 0  2022_oct_china_chip_export_control          NaN     0.050561
# 1           2023_chip_export_controls          NaN     0.048707
# 2    2023_mineral_export_restrictions          NaN     0.015520
# 3             2023_aug_investment_ban     0.018540     0.057864
# 4               2023_export_expansion    -0.005390          NaN
# 5        2024_march_export_tightening          NaN          NaN
# 6     2024_tariff_increase_ev_battery     0.012570          NaN
# 7            2024_tariff_finalization          NaN    -0.029281
# 8         2024_nvidia_antitrust_probe     0.059103          NaN
